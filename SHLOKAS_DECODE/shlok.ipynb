# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Dataset2.xlsx")

# %%
detected_mood = input("Enter mood : ")
# Out:
# Enter mood :  happy

# %%
import random
if detected_mood.lower() == "happy":
    num = random.sample(range(2,22), 4)
    print("Random numbers:", num)
elif detected_mood.lower() == "sad":
    num = random.sample(range(22,42), 4)
    print("Random numbers:", num)
elif detected_mood.lower() == "angry":
    num = random.sample(range(42,62), 4)
    print("Random numbers:", num)
elif detected_mood.lower() == "fear":
    num = random.sample(range(62,82), 4)
    print("Random numbers:", num)
elif detected_mood.lower() == "surprise":
    num = random.sample(range(82,102), 4)
    print("Random numbers:", num)
elif detected_mood.lower() == "disgust":
    num = random.sample(range(102,122), 4)
    print("Random numbers:", num)
elif detected_mood.lower() == "love":
    num = random.sample(range(122,142), 4)
    print("Random numbers:", num)
elif detected_mood.lower() == "netral":
    num = random.sample(range(142,162), 4)
    print("Random numbers:", num)
elif detected_mood.lower() == "excited":
    num = random.sample(range(162,182), 4)
    print("Random numbers:", num)
elif detected_mood.lower() == "bored":
    num = random.sample(range(182,202), 4)
    print("Random numbers:", num)
# Out:
# Random numbers: [14, 6, 2, 3]

# %%
for i in num:
    print(df.iloc[i,1])
    print(df.iloc[i,2])
# Out:
# रागद्वेषवियुक्तैस्तु विषयानिन्द्रियैश्‌चरन्॥
# One who moves amidst sense objects free from attachment and aversion attains peace.
# मय्येव मन आधत्स्व मयि बुद्धिं निवेशय॥
# Fix your mind and intellect on Me alone, and you will live in Me.
# न हि ज्ञानेन सदृशं पवित्रमिह विद्यते॥
# There is nothing as pure as knowledge in this world.
# यो मां पश्यति सर्वत्र सर्वं च मयि पश्यति॥
# One who sees Me everywhere and everything in Me is never separated from Me.
